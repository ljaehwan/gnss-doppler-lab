# %% [markdown]
# # 00. GNSS 스푸핑 탐지 연구 시퀀스
#
# ## 연구 목적
# 전체 연구를 순서대로 나누고, 각 단계 산출물의 준비 상태를 한 화면에서 확인합니다.
#
# ## 입력
# `artifacts/` 아래의 정상 IQ, 수신기 관측값, 스푸핑 IQ, 비교표, 특징 데이터셋입니다.
#
# > 이 Notebook부터 실행한 뒤 준비된 단계로 이동합니다.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "pyproject.toml").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "pyproject.toml").exists():
    raise RuntimeError("저장소 루트 또는 notebooks/에서 Notebook을 실행하세요.")
sys.path.insert(0, str(PROJECT_ROOT / "src"))
ARTIFACTS = PROJECT_ROOT / "artifacts"
print("PROJECT_ROOT:", PROJECT_ROOT)

# %% [markdown]
# ## 중간 확인 — 단계별 준비 상태
# 아래 표에서 `ready=True`인 단계는 데이터를 열어 분석할 수 있습니다.

# %%
from gnss_doppler_lab.research_sequence import sequence_status

status = sequence_status(ARTIFACTS)
print(f"{'단계':<30} {'준비':<6} 경로")
print('-' * 100)
for stage, info in status.items():
    print(f"{stage:<30} {str(info['ready']):<6} {info['path'] or '-'}")

# %% [markdown]
# ## 판정
#
# - 01 정상 IQ가 준비되어야 RF 기초 검증을 시작합니다.
# - 02 이후는 앞 단계 산출물이 있을 때만 분석합니다.
# - 한 단계를 통과했다는 판단은 그래프뿐 아니라 해당 Notebook의 체크리스트와 manifest를 함께 확인합니다.
#
# ## 다음 단계
# `01_normal_iq_generation_and_inspection.ipynb`에서 정상 IQ와 manifest를 확인합니다.
